# %%
using Yao, BitBasis, Plots

# %%
n=3
zero_state(n) |> repeat(n, X) |> measure! |> bint
# Out:
# 7

# %%
numbers = zero_state(n) |> repeat(n, H) |> r -> measure(r, nshots=10000) .|> bint
histogram(numbers, legend=:none, xticks=(0:maximum(numbers)), bar_width=0.9)
